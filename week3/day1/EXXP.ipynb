# %% [markdown]
# #Exercise 1: Introduction to Data Analysis
# Data analysis is the process of collecting, cleaning, transforming and modelling data — whether numbers, text, measurements — with the goal of discovering useful information, drawing conclusions, and supporting decision-making
# Parce que les entreprises et organisations ont énormément de données.Ça aide à prendre des décisions basées sur des faits, pas sur l’intuition.Ça permet de prédire, optimiser, gagner du temps, gagner de l’argent, et réduire les erreurs.Essentiel dans un monde numérique (AI, big data, e-commerce, santé…).Ça aide à prendre des décisions basées sur des faits, pas sur l’intuition.
# Ça permet de prédire, optimiser, gagner du temps, gagner de l’argent, et réduire les erreurs.
# Essentiel dans un monde numérique (AI, big data, e-commerce, santé…).
# Business & Marketing
# Comprendre les clients
# Recommander des produits
#
# Prévoir les ventes
#
# Optimiser les stocks
#
# 2. Healthcare (Santé)
#
# Analyser des dossiers médicaux
#
# Aider au diagnostic
#
# Prévoir les maladies
#
# Planifier les ressources des hôpitaux
#
# 3. Science & Environment
#
# Étudier les données climatiques
#
# Analyser des expériences scientifiques
#
# Suivre la pollution ou les phénomènes naturels
# #Exercise 2: Dataset Loading and Initial Analysis

# %% [markdown]
# #EXERCICE2

# %%
import pandas as pd

# %%
df = pd.read_csv('Time Americans Spend Sleeping.csv')

# %%
display(df.head())
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
df.dtypes
# Out:
# index                         int64
# Year                          int64
# Period                       object
# Avg hrs per day sleeping    float64
# Standard Error              float64
# Type of Days                 object
# Age Group                    object
# Activity                     object
# Sex                          object
# dtype: object

# %%
quantitative_cols = df.select_dtypes(include=['int64', 'float64']).columns
qualitative_cols = df.select_dtypes(include=['object']).columns

print("Quantitative columns:", quantitative_cols)
print("Qualitative columns:", qualitative_cols)
# Out:
# Quantitative columns: Index(['index', 'Year', 'Avg hrs per day sleeping', 'Standard Error'], dtype='object')
# Qualitative columns: Index(['Period', 'Type of Days', 'Age Group', 'Activity', 'Sex'], dtype='object')

# %% [markdown]
# #It shows how much time a specific demographic spends sleeping over several years.
# #From this small snippet, we can observe a slight upward trend in sleep duration.
# #The average number of hours slept increased from 8.57 hours in 2003 to 8.63 #hours in 2006.

# %%
df=pd.read_csv('Mental health Depression disorder Data.csv')
# Out:
# C:\Users\pro\AppData\Local\Temp\ipykernel_32036\4257540648.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Mental health Depression disorder Data.csv')

# %%
display(df.head())
# Out:
#    ndex       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0     0  Afghanistan  AFG  1990           0.16056             0.697779
# 1     1  Afghanistan  AFG  1991          0.160312             0.697961
# 2     2  Afghanistan  AFG  1992          0.160135             0.698107
# 3     3  Afghanistan  AFG  1993          0.160037             0.698257
# 4     4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %% [markdown]
# # This dataset shows the prevalence (%) of different mental health disorders in Afghanistan over several years.
# # Each row represents one year, starting from 1990.
# # The columns include:
# # - Schizophrenia
# # - Bipolar disorder
# # - Eating disorders
# # - Anxiety disorders
# # - Drug use disorders
# # - Depression
# # - Alcohol use disorders
# #
# # From the first few rows, we can see that:
# # - Schizophrenia and bipolar disorder remain almost stable over the years.
# # - Anxiety disorders are the most common, with values above 4%.
# # - Depression rates are also high compared to other disorders.
# # - Eating disorders have the lowest percentages.

# %%
df=pd.read_csv('clean_dataset.csv')
display(df.head())
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %% [markdown]
# This dataset contains information about credit card applicants and whether their application was approved.
# Each row represents an applicant, with features like age, gender, debt, income, employment, and prior defaults.
# The Approved column shows if the credit was granted (1) or not (0).

# %%
df.dtypes
# Out:
# Gender              int64
# Age               float64
# Debt              float64
# Married             int64
# BankCustomer        int64
# Industry           object
# Ethnicity          object
# YearsEmployed     float64
# PriorDefault        int64
# Employed            int64
# CreditScore         int64
# DriversLicense      int64
# Citizen            object
# ZipCode             int64
# Income              int64
# Approved            int64
# dtype: object

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print("qualitative_cols", qualitative_cols)
print("quantitative_cols", quantitative_cols)
# Out:
# qualitative_cols Index(['Period', 'Type of Days', 'Age Group', 'Activity', 'Sex'], dtype='object')
# quantitative_cols Index(['index', 'Year', 'Avg hrs per day sleeping', 'Standard Error'], dtype='object')

# %%
description = {
    'sepal_length': 'Quantitative : longueur du sépale en cm, valeur numérique continue',
    'sepal_width': 'Quantitative : largeur du sépale en cm, valeur numérique continue',
    'petal_length': 'Quantitative : longueur du pétale en cm, valeur numérique continue',
    'petal_width': 'Quantitative : largeur du pétale en cm, valeur numérique continue',
    'species': 'Qualitative : espèce de la fleur, catégorie discrète (setosa, versicolor, virginica)'
}

# %%
print("\nDescription des colonnes :")
for col, desc in description.items():
    print(f"{col} -> {desc}")
# Out:
# Description des colonnes :
# sepal_length -> Quantitative : longueur du sépale en cm, valeur numérique continue
# sepal_width -> Quantitative : largeur du sépale en cm, valeur numérique continue
# petal_length -> Quantitative : longueur du pétale en cm, valeur numérique continue
# petal_width -> Quantitative : largeur du pétale en cm, valeur numérique continue
# species -> Qualitative : espèce de la fleur, catégorie discrète (setosa, versicolor, virginica)

# %%
import pandas as pd

df = pd.read_csv("iris.csv")

df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
quantitative = ["sepal_length", "sepal_width", "petal_length", "petal_width"]
qualitative = ["species"]

quantitative, qualitative
# Out:
# (['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], ['species'])

# %%
df['SepalLengthCm'].mean()
# Out:
# np.float64(5.843333333333334)

# %%
df['SepalLengthCm'].median()
# Out:
# np.float64(5.8)

# %%
df['SepalLengthCm'].mode()
# Out:
# 0    5.0
# Name: SepalLengthCm, dtype: float64

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(df['SepalLengthCm'])
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()

# %%
df=pd.read_csv('Time Americans Spend Sleeping.csv')

# %%
df.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
df.columns
# Out:
# Index(['index', 'Year', 'Period', 'Avg hrs per day sleeping', 'Standard Error',
#        'Type of Days', 'Age Group', 'Activity', 'Sex'],
#       dtype='object')

# %%
trend_columns = ["year","month"]
group_columns=["gender","age_group","employment_status","sleep_duration_category"]
quantitative_columns=["average_sleep_hours","sleep_quality"]
trend_columns,group_columns,quantitative_columns
# Out:
# (['year', 'month'],
#  ['gender', 'age_group', 'employment_status', 'sleep_duration_category'],
#  ['average_sleep_hours', 'sleep_quality'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns   
plt.hist(['average_sleep_hours'])
plt.xlabel('Average Sleep Hours')       
plt.ylabel('Frequency')
plt.title('Histogram of Average Sleep Hours')
plt.show()
